# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import os

# %%
pd.set_option("display.max_columns", 999)

# %%
# 시간별 정렬 필요

# %%
first_drive = os.listdir('1st_drive') # 압력 센서가 없다
df = pd.DataFrame()
for i in first_drive:
    x = pd.read_csv('1st_drive/'+i,parse_dates=['Time (-)'])
    x['path'] = i[23:-4]
    df = df.append(x)
df.head()
# Out:
#          Date             Time (-)  LF_TTPMS_T1 -  (_C)  LF_TTPMS_T2 -  (_C)  \
# 0  2020-10-24  2020-11-13 04:41:30                  NaN                  NaN
# 1  2020-10-24  2020-11-13 04:41:30                  NaN                  NaN
# 2  2020-10-24  2020-11-13 04:41:30                  NaN                  NaN
# 3  2020-10-24  2020-11-13 04:41:30                  NaN                  NaN
# 4  2020-10-24  2020-11-13 04:41:30                  NaN                  NaN
#
#    LF_TTPMS_T3 -  (_C)  LF_TTPMS_T4 -  (_C)  LF_TTPMS_T5 -  (_C)  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    LF_TTPMS_T6 -  (_C)  LF_TTPMS_T7 -  (_C)  LF_TTPMS_T8 -  (_C)  ...  \
# ...

# %%
df_sample = df.sort_values('Distance (m)').reset_index(drop=True)
plt.plot(df_sample['Distance (m)'])

# %%
df_sample['Distance (m)'][0]
# Out:
# 1684.12

# %%
df_sample.tail()
# Out:
#                Date             Time (-)  LF_TTPMS_T1 -  (_C)  \
# 2719382  2020-10-24  2020-11-13 04:48:48                  NaN
# 2719383  2020-10-24  2020-11-13 04:48:48                  NaN
# 2719384  2020-10-24  2020-11-13 04:48:48                  NaN
# 2719385  2020-10-24  2020-11-13 04:48:48                  NaN
# 2719386  2020-10-24  2020-11-13 04:48:48                  NaN
#
#          LF_TTPMS_T2 -  (_C)  LF_TTPMS_T3 -  (_C)  LF_TTPMS_T4 -  (_C)  \
# 2719382                  NaN                  NaN                  NaN
# 2719383                  NaN                  NaN                  NaN
# 2719384                  NaN                  NaN                  NaN
# 2719385                  NaN                  NaN                  NaN
# 2719386                  NaN                  NaN                  NaN
#
#          LF_TTPMS_T5 -  (_C)  LF_TTPMS_T6 -  (_C)  LF_TTPMS_T7 -  (_C)  \
# 2719382                  NaN                  NaN                  NaN
# ...

# %%
first_drive = os.listdir('1st_drive') # 압력 센서가 없다

x = pd.read_csv('1st_drive/'+first_drive[0],parse_dates=['Time (-)'])
x['path'] = first_drive[0][23:-4]
x
# Out:
#              Date            Time (-)  LF_TTPMS_T1 -  (_C)  \
# 0      2020-10-24 2020-11-13 04:41:30                  NaN
# 1      2020-10-24 2020-11-13 04:41:30                  NaN
# 2      2020-10-24 2020-11-13 04:41:30                  NaN
# 3      2020-10-24 2020-11-13 04:41:30                  NaN
# 4      2020-10-24 2020-11-13 04:41:30                  NaN
# ...           ...                 ...                  ...
# 94090  2020-10-24 2020-11-13 06:15:36                  NaN
# 94091  2020-10-24 2020-11-13 06:15:36                  NaN
# 94092  2020-10-24 2020-11-13 06:15:36                  NaN
# 94093  2020-10-24 2020-11-13 06:15:36                  NaN
# 94094  2020-10-24 2020-11-13 06:15:36                  NaN
#
#        LF_TTPMS_T2 -  (_C)  LF_TTPMS_T3 -  (_C)  LF_TTPMS_T4 -  (_C)  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# ...

# %%
first_drive = os.listdir('1st_drive') # 압력 센서가 없다

x2 = pd.read_csv('1st_drive/'+'Test_2020_10_24_060304 동부산대학_고촌.csv',parse_dates=['Time (-)'])
x2['path'] = first_drive[0][23:-4]
x2
# Out:
#              Date            Time (-)  LF_TTPMS_T1 -  (_C)  \
# 0      2020-10-24 2020-11-13 01:12:00                  NaN
# 1      2020-10-24 2020-11-13 01:12:00                  NaN
# 2      2020-10-24 2020-11-13 01:12:00                  NaN
# 3      2020-10-24 2020-11-13 01:12:00                  NaN
# 4      2020-10-24 2020-11-13 01:12:00                  NaN
# ...           ...                 ...                  ...
# 89530  2020-10-24 2020-11-13 02:41:30                  NaN
# 89531  2020-10-24 2020-11-13 02:41:30                  NaN
# 89532  2020-10-24 2020-11-13 02:41:30                  NaN
# 89533  2020-10-24 2020-11-13 02:41:30                  NaN
# 89534  2020-10-24 2020-11-13 02:41:30                  NaN
#
#        LF_TTPMS_T2 -  (_C)  LF_TTPMS_T3 -  (_C)  LF_TTPMS_T4 -  (_C)  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# ...

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=x2['Time (-)'],y=x2['X (G)'])
plt.title('X (G)')
# Out:
# Text(0.5, 1.0, 'X (G)')

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=x2['Time (-)'],y=x2['Y (G)'])
plt.title('Y (G)')
# Out:
# Text(0.5, 1.0, 'Y (G)')

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=x2['Time (-)'],y=x2['Z (G)'])
plt.title('Z (G)')
# Out:
# Text(0.5, 1.0, 'Z (G)')

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=x2['Time (-)'],y=x2['Velocity (Km/h)'])
plt.title('Velocity (Km/h)')
# Out:
# Text(0.5, 1.0, 'Velocity (Km/h)')

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=x['Time (-)'],y=x['X (G)'])
plt.title('X (G)')
# Out:
# Text(0.5, 1.0, 'X (G)')

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=x['Time (-)'],y=x['Y (G)'])
plt.title('Y (G)')
# Out:
# Text(0.5, 1.0, 'Y (G)')

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=x['Time (-)'],y=x['Z (G)'])
plt.title('Z (G)')
# Out:
# Text(0.5, 1.0, 'Z (G)')

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=x['Time (-)'],y=x['Velocity (Km/h)'])
plt.title('Velocity (Km/h)')
# Out:
# Text(0.5, 1.0, 'Velocity (Km/h)')

# %%
tmp = pd.DataFrame(columns=x.columns[2:-6])
for k in x.columns[2:-6]:
    tmp[k] = np.array(x[k].dropna())
tmp
# Out:
#       LF_TTPMS_T1 -  (_C)  LF_TTPMS_T2 -  (_C)  LF_TTPMS_T3 -  (_C)  \
# 0                    12.4                 13.9            14.100000
# 1                    12.4                 13.9            14.100000
# 2                    12.4                 13.9            14.100000
# 3                    12.4                 13.9            14.100000
# 4                    12.4                 13.9            14.100000
# ...                   ...                  ...                  ...
# 1507                 16.9                 16.5            18.200001
# 1508                 16.9                 16.5            18.200001
# 1509                 16.9                 16.5            18.200001
# 1510                 16.9                 16.5            18.200001
# 1511                 16.9                 16.5            18.200001
#
#       LF_TTPMS_T4 -  (_C)  LF_TTPMS_T5 -  (_C)  LF_TTPMS_T6 -  (_C)  \
# 0               13.600000            14.000000                 13.9
# ...

# %%
plt.figure(figsize=(12,8))
plt.plot(tmp['LF_TTPMS_T1 -  (_C)'])

# %%
second_drive = os.listdir('2nd_drive')
df2 = pd.DataFrame()
for i in second_drive:
    x = pd.read_csv('2nd_drive/'+i,parse_dates=['Time (-)'])
    x['path'] = i[23:-4]
    df2 = df2.append(x)
df2.head()
# Out:
#          Date             Time (-)  LF_TTPMS_T1 -  (_C)  LF_TTPMS_T2 -  (_C)  \
# 0  2020-10-24  2020-11-13 07:57:06                  NaN                  NaN
# 1  2020-10-24  2020-11-13 07:57:06                  NaN                  NaN
# 2  2020-10-24  2020-11-13 07:57:06                  NaN                  NaN
# 3  2020-10-24  2020-11-13 07:57:06                  NaN                  NaN
# 4  2020-10-24  2020-11-13 07:57:06                  NaN                  NaN
#
#    LF_TTPMS_T3 -  (_C)  LF_TTPMS_T4 -  (_C)  LF_TTPMS_T5 -  (_C)  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    LF_TTPMS_T6 -  (_C)  LF_TTPMS_T7 -  (_C)  LF_TTPMS_T8 -  (_C)  ...  \
# ...

# %%
고촌2 = pd.read_csv('C:/Users/CVAI/Downloads/kym/Tire/1024/2nd_drive/Test_2020_10_24_060304 고촌_동부산대학.csv',parse_dates=['Time (-)'])

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=고촌2['Time (-)'],y=고촌2['X (G)'])
plt.title('X (G)')
# Out:
# Text(0.5, 1.0, 'X (G)')

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=고촌2['Time (-)'],y=고촌2['Y (G)'])
plt.title('Y (G)')
# Out:
# Text(0.5, 1.0, 'Y (G)')

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=고촌2['Time (-)'],y=고촌2['Z (G)'])
plt.title('Z (G)')
# Out:
# Text(0.5, 1.0, 'Z (G)')

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=고촌2['Time (-)'],y=고촌2['Velocity (Km/h)'])
plt.title('Velocity (Km/h)')
# Out:
# Text(0.5, 1.0, 'Velocity (Km/h)')

# %%
고촌3 = pd.read_csv('C:/Users/CVAI/Downloads/kym/Tire/1024/2nd_drive/Test_2020_10_24_060304 동부산대학_고촌.csv',parse_dates=['Time (-)'])

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=고촌2['Time (-)'],y=고촌2['X (G)'])
plt.title('X (G)')
# Out:
# Text(0.5, 1.0, 'X (G)')

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=고촌2['Time (-)'],y=고촌2['Y (G)'])
plt.title('Y (G)')
# Out:
# Text(0.5, 1.0, 'Y (G)')

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=고촌2['Time (-)'],y=고촌2['Z (G)'])
plt.title('Z (G)')
# Out:
# Text(0.5, 1.0, 'Z (G)')

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=고촌2['Time (-)'],y=고촌2['Velocity (Km/h)'])
plt.title('Velocity (Km/h)')
# Out:
# Text(0.5, 1.0, 'Velocity (Km/h)')

# %%
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
def lag_finder(y1, y2):
    n = len(y1)
    corr = signal.correlate(y2, y1, mode='same',method='fft') / np.sqrt(signal.correlate(y1, y1, mode='same',method='fft')[int(n/2)] \
                                                           * signal.correlate(y2, y2, mode='same',method='fft')[int(n/2)])
    return corr

# %%
corr = lag_finder(x['X (G)'],x['Velocity (Km/h)'])
plt.plot(corr)

# %%
x[['X (G)','Y (G)','Z (G)','Velocity (Km/h)']].corr()
# Out:
#                     X (G)     Y (G)     Z (G)  Velocity (Km/h)
# X (G)            1.000000  0.014299  0.070821         0.004352
# Y (G)            0.014299  1.000000 -0.127021         0.019806
# Z (G)            0.070821 -0.127021  1.000000         0.001166
# Velocity (Km/h)  0.004352  0.019806  0.001166         1.000000

# %%
temp = pd.read_csv('Test_2020_10_24_060304 온도 압력(1).csv')

# %%
tim = pd.read_csv('Test_2020_10_24_060304 온도 압력 - 역도착시간.csv',engine='python')

# %%
tim['Time'][1]
# Out:
# '04:42.3'

# %%
import pandas as pd
df = pd.read_csv('Test_2020_10_24_060304 온도 압력(1).csv')
dfx = df['Time (-)'] >= tim['Time'][1]
dfy = df['Time (-)'] <= tim['Time'][2]
dfz = df[dfx & dfy]
dfz = dfz.reset_index(drop=True)
# Out:
#               Date Time (-)  LF_TTPMS_P -  (mbar)  LF_TTPMS_T1 -  (_C)  \
# 8724    2020-10-24  04:42.3               10036.0                  NaN
# 8725    2020-10-24  04:42.3                   NaN                 12.4
# 8726    2020-10-24  04:42.3                   NaN                  NaN
# 8727    2020-10-24  04:42.3                   NaN                  NaN
# 8728    2020-10-24  04:42.3                   NaN                  NaN
# ...            ...      ...                   ...                  ...
# 983358  2020-10-24  06:25.7                   NaN                  NaN
# 983359  2020-10-24  06:25.7                   NaN                  NaN
# 983360  2020-10-24  06:25.7                   NaN                  NaN
# 983361  2020-10-24  06:25.7                   NaN                  NaN
# 983362  2020-10-24  06:25.7                   NaN                  NaN
#
#         LF_TTPMS_T2 -  (_C)  LF_TTPMS_T3 -  (_C)  LF_TTPMS_T4 -  (_C)  \
# ...

# %%
for i in range(df.shape[0]):
    if df['Time (-)'][i] == tim['Time'][1]:
        print(i)
# Out:
# 8724
# 8725
# 8726
# 8727
# 8728
# 8729
# 8730
# 8731
# 8732
# 8733
# 8734
# 331185
# 331186
# 331187
# 331188
# 331189
# 653032
# 653033
# 653034
# 653035
# 653036
# 974149
# 974150
# 974151
# 974152
# 974153
# 974154
# 974155
# 974156
# 974157
# 974158
# 974159

# %%
for j in range(df.shape[0]):
    if df['Time (-)'][j] == tim['Time'][2]:
        print(j)
# Out:
# 17901
# 17902
# 17903
# 17904
# 17905
# 17906
# 17907
# 17908
# 17909
# 17910
# 17911
# 340414
# 340415
# 340416
# 340417
# 340418
# 340419
# 340420
# 340421
# 340422
# 340423
# 340424
# 662222
# 662223
# 662224
# 662225
# 662226
# 662227
# 662228
# 662229
# 662230
# 662231
# 662232
# 983357
# 983358
# 983359
# 983360
# 983361
# 983362

# %%
dfz = df.iloc[8724:17911]

# %%
tmp = pd.DataFrame(columns=dfz.columns[2:19])
for k in dfz.columns[2:19]:
    tmp[k] = np.array(dfz[k].dropna())
tmp
# Out:
#       LF_TTPMS_P -  (mbar)  LF_TTPMS_T1 -  (_C)  LF_TTPMS_T2 -  (_C)  \
# 0                  10036.0                 12.4                 13.9
# 1                  10036.0                 12.4                 13.9
# 2                  10036.0                 12.4                 13.9
# 3                  10036.0                 12.4                 13.9
# 4                  10036.0                 11.6                 14.4
# ...                    ...                  ...                  ...
# 1659               10066.0                 13.8                 15.7
# 1660               10066.0                 13.8                 15.7
# 1661               10066.0                 13.8                 15.7
# 1662               10066.0                 13.8                 15.7
# 1663               10066.0                 13.8                 15.7
#
#       LF_TTPMS_T3 -  (_C)  LF_TTPMS_T4 -  (_C)  LF_TTPMS_T5 -  (_C)  \
# 0                    14.1            13.600000                 14.0
# ...

# %%
fig, ax1 = plt.subplots(figsize=(20,12))
ax1.plot(tmp['LF_TTPMS_P -  (mbar)'],color='red')
ax2=ax1.twinx()
for i in range(1,17):
    ax2.plot(tmp['LF_TTPMS_T{} -  (_C)'.format(i)],label = 'LF_TTPMS_T{} -  (_C)'.format(i))

fig.legend()

# %%
gochon2 = temp.iloc[8724:17911]
